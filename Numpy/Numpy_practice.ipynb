# %%
import sys

print(sys.executable)
# Out:
# c:\Users\majom\OneDrive\Desktop\Python Libraries\Numpy\venv\Scripts\python.exe

# %%
import numpy as np

arr = np.array([1, 2, 3, 4, 5])
print(arr)
# Out:
# [1 2 3 4 5]
